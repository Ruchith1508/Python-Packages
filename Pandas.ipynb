# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df1=pd.read_csv("mesh_dataset.txt")

# %%
df2=pd.read_json("carshare_data.json")

# %%
df3=pd.read_excel("data-matlab-excel-example.xlsx",sheet_name=0)

# %%
df=pd.read_csv("GanttChart.csv")

# %%
df.head()
# Out:
#      Task      Start  Duration Resource
# 0  Task 1   1/1/2016        50        A
# 1  Task 2  2/20/2016        25        B
# 2  Task 3   1/1/2016       100        C
# 3  Task 4  4/10/2016        60        C
# 4  Task 5   6/9/2016        30        C

# %%
df.head(10)
# Out:
#      Task       Start  Duration Resource
# 0  Task 1    1/1/2016        50        A
# 1  Task 2   2/20/2016        25        B
# 2  Task 3    1/1/2016       100        C
# 3  Task 4   4/10/2016        60        C
# 4  Task 5    6/9/2016        30        C
# 5  Task 6   4/10/2016       150        A
# 6  Task 7    9/7/2016        80        B
# 7  Task 8  11/26/2016        10        B

# %%
df.tail()
# Out:
#      Task       Start  Duration Resource
# 3  Task 4   4/10/2016        60        C
# 4  Task 5    6/9/2016        30        C
# 5  Task 6   4/10/2016       150        A
# 6  Task 7    9/7/2016        80        B
# 7  Task 8  11/26/2016        10        B

# %%
df.tail(3)
# Out:
#      Task       Start  Duration Resource
# 5  Task 6   4/10/2016       150        A
# 6  Task 7    9/7/2016        80        B
# 7  Task 8  11/26/2016        10        B

# %%
df.columns
# Out:
# Index(['Task', 'Start', 'Duration', 'Resource'], dtype='object')

# %%
list(df.columns)
# Out:
# ['Task', 'Start', 'Duration', 'Resource']

# %%
df.describe()
# Out:
#          Duration
# count    8.000000
# mean    63.125000
# std     45.898763
# min     10.000000
# 25%     28.750000
# 50%     55.000000
# 75%     85.000000
# max    150.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Task      8 non-null      object
#  1   Start     8 non-null      object
#  2   Duration  8 non-null      int64
#  3   Resource  8 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 384.0+ bytes

# %%
df.isnull()
# Out:
#     Task  Start  Duration  Resource
# 0  False  False     False     False
# 1  False  False     False     False
# 2  False  False     False     False
# 3  False  False     False     False
# 4  False  False     False     False
# 5  False  False     False     False
# 6  False  False     False     False
# 7  False  False     False     False

# %%
df.isnull().any()
# Out:
# Task        False
# Start       False
# Duration    False
# Resource    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Task        0
# Start       0
# Duration    0
# Resource    0
# dtype: int64

# %%
df.isna()
# Out:
#     Task  Start  Duration  Resource
# 0  False  False     False     False
# 1  False  False     False     False
# 2  False  False     False     False
# 3  False  False     False     False
# 4  False  False     False     False
# 5  False  False     False     False
# 6  False  False     False     False
# 7  False  False     False     False

# %%
df.isna().sum()
# Out:
# Task        0
# Start       0
# Duration    0
# Resource    0
# dtype: int64
